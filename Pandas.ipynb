# %%
import pandas as pd

# %% [markdown]
# Manually create a dataframe

# %%
df = pd.DataFrame({
    'Name': ['Anirban', 'jhon', 'Ben', 'Lisa'],
    'Age': [27,23,56,90],
    'Sex': ['M', 'M', 'M', 'F']
})
df
# Out:
#       Name  Age Sex
# 0  Anirban   27   M
# 1     jhon   23   M
# 2      Ben   56   M
# 3     Lisa   90   F

# %% [markdown]
# Each column is a pandas series

# %%
df['Age']
# Out:
# 0    27
# 1    23
# 2    56
# 3    90
# Name: Age, dtype: int64

# %%
age = pd.Series([27,23,56,90], name = 'Age')
age
# Out:
# 0    27
# 1    23
# 2    56
# 3    90
# Name: Age, dtype: int64

# %%
print(df['Age'].max())
print(df['Age'].min())
print(df['Age'].mean())
print(age.max())
print(age.min())
print(age.mean())
# Out:
# 90
# 23
# 49.0
# 90
# 23
# 49.0

# %%
df.describe()
# Out:
#              Age
# count   4.000000
# mean   49.000000
# std    31.037612
# min    23.000000
# 25%    26.000000
# 50%    41.500000
# 75%    64.500000
# max    90.000000

# %%
pokemon = pd.read_csv('pokemon_data.csv')

pokemon
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
pokemon.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pokemon.tail(5)
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
pokemon.dtypes
# Out:
# #              int64
# Name          object
# Type 1        object
# Type 2        object
# HP             int64
# Attack         int64
# Defense        int64
# Sp. Atk        int64
# Sp. Def        int64
# Speed          int64
# Generation     int64
# Legendary       bool
# dtype: object

# %%
pokemon.to_excel('pokemon_data.xlsx', sheet_name='pokemon_species', index = False)

# %%
pokemon = pd.read_excel('pokemon_data.xlsx', sheet_name='pokemon_species')

pokemon.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %% [markdown]
# The method info() provides technical information about a DataFrame

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %% [markdown]
# Subsetting dataframe by column

# %%
pokemon_names = pokemon['Name']

pokemon_names.head(5)
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %%
type(pokemon_names)
# Out:
# pandas.core.series.Series

# %%
print(pokemon.shape)
print(pokemon_names.shape)
# Out:
# (800, 12)
# (800,)

# %%
pokemon[['Name', 'Type 1']].head(5)
# Out:
#                     Name Type 1
# 0              Bulbasaur  Grass
# 1                Ivysaur  Grass
# 2               Venusaur  Grass
# 3  VenusaurMega Venusaur  Grass
# 4             Charmander   Fire

# %% [markdown]
# Filtering of rows

# %%
pokemon.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
speed_above_60 = pokemon[pokemon['Speed'] > 60]

print(speed_above_60.shape)

speed_above_60.head(5)
# Out:
# (436, 12)
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
# 5  5             Charmeleon   Fire     NaN  58      64       58       80
# 6  6              Charizard   Fire  Flying  78      84       78      109
#
#    Sp. Def  Speed  Generation  Legendary
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False
# 5       65     80           1      False
# 6       85    100           1      False

# %%
pokemon['Speed'] > 60
# Out:
# 0      False
# 1      False
# 2       True
# 3       True
# 4       True
#        ...
# 795    False
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Speed, Length: 800, dtype: bool

# %%
pokemon['Type 1'].unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
grass_fire = pokemon[pokemon['Type 1'].isin(['Grass', 'Fire'])]

print(grass_fire.shape)

grass_fire.tail(5)
# Out:
# (122, 12)
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 735  667     Litleo   Fire  Normal   62      50       58       73       54
# 736  668     Pyroar   Fire  Normal   86      68       72      109       66
# 740  672     Skiddo  Grass     NaN   66      65       48       62       57
# 741  673     Gogoat  Grass     NaN  123     100       62       97       81
# 799  721  Volcanion   Fire   Water   80     110      120      130       90
#
#      Speed  Generation  Legendary
# 735     72           6      False
# 736    106           6      False
# 740     52           6      False
# 741     68           6      False
# 799     70           6       True

# %%
grass_fire = pokemon[(pokemon['Type 1'] == 'Grass') | (pokemon['Type 1'] == 'Fire')]

print(grass_fire.shape)

grass_fire.tail(5)
# Out:
# (122, 12)
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 735  667     Litleo   Fire  Normal   62      50       58       73       54
# 736  668     Pyroar   Fire  Normal   86      68       72      109       66
# 740  672     Skiddo  Grass     NaN   66      65       48       62       57
# 741  673     Gogoat  Grass     NaN  123     100       62       97       81
# 799  721  Volcanion   Fire   Water   80     110      120      130       90
#
#      Speed  Generation  Legendary
# 735     72           6      False
# 736    106           6      False
# 740     52           6      False
# 741     68           6      False
# 799     70           6       True

# %%
na_rows = pokemon[pokemon['Type 2'].isna()]

print(na_rows.shape)

na_rows.tail(5)
# Out:
# (386, 12)
#        #      Name  Type 1 Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 775  705   Sliggoo  Dragon    NaN   68      75       53       83      113
# 776  706    Goodra  Dragon    NaN   90     100       70      110      150
# 788  712  Bergmite     Ice    NaN   55      69       85       32       35
# 789  713   Avalugg     Ice    NaN   95     117      184       44       46
# 792  716   Xerneas   Fairy    NaN  126     131       95      131       98
#
#      Speed  Generation  Legendary
# 775     60           6      False
# 776     80           6      False
# 788     28           6      False
# 789     28           6      False
# 792     99           6       True

# %%
not_na_rows = pokemon[pokemon['Type 2'].notna()]

print(not_na_rows.shape)

not_na_rows.tail(5)
# Out:
# (414, 12)
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk  \
# 795  719              Diancie     Rock  Fairy  50     100      150      100
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
pokemon[pokemon['Speed'] > 80]['Name'].head(5)
# Out:
# 6                     Charizard
# 7     CharizardMega Charizard X
# 8     CharizardMega Charizard Y
# 19        BeedrillMega Beedrill
# 22                      Pidgeot
# Name: Name, dtype: object

# %% [markdown]
# When using the column names, row labels or a condition expression, use the loc operator in front of the selection brackets [].

# %%
pokemon.loc[pokemon['Speed'] > 80, ['Name', 'Speed']].head(5)
# Out:
#                          Name  Speed
# 6                   Charizard    100
# 7   CharizardMega Charizard X    100
# 8   CharizardMega Charizard Y    100
# 19      BeedrillMega Beedrill    145
# 22                    Pidgeot    101

# %% [markdown]
# When specifically interested in certain rows and/or columns based on their position in the table, use the iloc operator in front of the selection brackets [].

# %%
pokemon.iloc[9:25, 2:5].head(5)
# Out:
#    Type 1 Type 2  HP
# 9   Water    NaN  44
# 10  Water    NaN  59
# 11  Water    NaN  79
# 12  Water    NaN  79
# 13    Bug    NaN  45

# %%
pokemon.iloc[0:3, 1] = "anonymous"

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1                  anonymous  Grass  Poison  45      49       49       65
# 1  2                  anonymous  Grass  Poison  60      62       63       80
# 2  3                  anonymous  Grass  Poison  80      82       83      100
# 3  3      VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4                 Charmander   Fire     NaN  39      52       43       60
# 5  5                 Charmeleon   Fire     NaN  58      64       58       80
# 6  6                  Charizard   Fire  Flying  78      84       78      109
# 7  6  CharizardMega Charizard X   Fire  Dragon  78     130      111      130
# 8  6  CharizardMega Charizard Y   Fire  Flying  78     104       78      159
# 9  7                   Squirtle  Water     NaN  44      48       65       50
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# ...

# %% [markdown]
# Plots using pandas

# %%
import matplotlib.pyplot as plt

# %%
weather = pd.read_csv('weather.csv', index_col=0, parse_dates=True)

weather.head()
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 2016-01-01           38        23        52                 30.03
# 2016-01-02           36        18        46                 30.02
# 2016-01-03           40        21        47                 29.86
# 2016-01-04           25         9        44                 30.05
# 2016-01-05           20        -3        41                 30.57
#
#             VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# EST
# 2016-01-01               10           8.0               0           5    NaN
# 2016-01-02               10           7.0               0           3    NaN
# 2016-01-03               10           8.0               0           1    NaN
# 2016-01-04               10           9.0               0           3    NaN
# 2016-01-05               10           5.0               0           0    NaN
#
#             WindDirDegrees
# EST
# 2016-01-01             281
# 2016-01-02             275
# ...

# %%
weather.plot()

# %%
weather[['Temperature', 'DewPoint', 'Humidity']].plot()

# %%
weather.plot.scatter(x = 'Humidity', y = 'Sea Level PressureIn', alpha = 0.5)

# %%
[
        method_name
        for method_name in dir(weather.plot)
        if not method_name.startswith("_")
    ]
# Out:
# ['area',
#  'bar',
#  'barh',
#  'box',
#  'density',
#  'hexbin',
#  'hist',
#  'kde',
#  'line',
#  'pie',
#  'scatter']

# %%
weather[['Temperature', 'DewPoint', 'Humidity']].plot.box()

# %%
weather[['Temperature', 'DewPoint', 'Humidity']].plot.hist(alpha = 0.7)

# %%
weather[['Temperature', 'DewPoint', 'Humidity']].plot.hist(figsize=(8, 10),subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000001CC8D73F280>,
# ...
#       dtype=object)

# %%
axs = weather[['Temperature', 'Humidity']].plot.area(figsize=(12, 4), subplots=True)

# %%
fig, axs = plt.subplots(figsize=(12, 4))  # Create an empty matplotlib Figure and Axes

weather[['Temperature', 'Humidity']].plot.area(ax = axs, alpha =0.7)  # Use pandas to put the area plot on the prepared Figure/Axes

axs.set_ylabel("temp and humidity")  # Do any matplotlib customization you like
# Out:
# Text(0, 0.5, 'temp and humidity')

# %% [markdown]
# Read data from url

# %%
url = "https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/air_quality_no2.csv"

air_quality = pd.read_csv(url, index_col=0, parse_dates=True)

air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN

# %%
air_quality["london_mg_per_cubic"] = air_quality["station_london"] * 1.882

air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# 2019-05-07 04:00:00               35.758
# 2019-05-07 05:00:00               30.112
# 2019-05-07 06:00:00                  NaN

# %%
air_quality["ratio_paris_antwerp"] = air_quality["station_paris"] / air_quality["station_antwerp"]

air_quality.head()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            19.0
# 2019-05-07 04:00:00             45.0           27.7            19.0
# 2019-05-07 05:00:00              NaN           50.4            16.0
# 2019-05-07 06:00:00              NaN           61.9             NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# 2019-05-07 04:00:00               35.758             0.615556
# 2019-05-07 05:00:00               30.112                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %%
air_quality_renamed = air_quality.rename(
        columns={
            "station_antwerp": "BETR801",
            "station_paris": "FR04014",
            "station_london": "London Westminster",
        }
    )

air_quality_renamed.head()
# Out:
#                      BETR801  FR04014  London Westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# 2019-05-07 04:00:00               35.758             0.615556
# 2019-05-07 05:00:00               30.112                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %%
air_quality_renamed = air_quality_renamed.rename(columns=str.lower)

air_quality_renamed.head()
# Out:
#                      betr801  fr04014  london westminster  \
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0
# 2019-05-07 03:00:00     50.5     25.0                19.0
# 2019-05-07 04:00:00     45.0     27.7                19.0
# 2019-05-07 05:00:00      NaN     50.4                16.0
# 2019-05-07 06:00:00      NaN     61.9                 NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# 2019-05-07 03:00:00               35.758             0.495050
# 2019-05-07 04:00:00               35.758             0.615556
# 2019-05-07 05:00:00               30.112                  NaN
# 2019-05-07 06:00:00                  NaN                  NaN

# %%
del air_quality_renamed['ratio_paris_antwerp']

air_quality_renamed.head()
# Out:
#                      betr801  fr04014  london westminster  london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00      NaN      NaN                23.0               43.286
# 2019-05-07 03:00:00     50.5     25.0                19.0               35.758
# 2019-05-07 04:00:00     45.0     27.7                19.0               35.758
# 2019-05-07 05:00:00      NaN     50.4                16.0               30.112
# 2019-05-07 06:00:00      NaN     61.9                 NaN                  NaN

# %%
air_quality_renamed.insert(1, "new_col", air_quality_renamed["london_mg_per_cubic"])

air_quality_renamed.head()
# Out:
#                      betr801  new_col  fr04014  london westminster  \
# datetime
# 2019-05-07 02:00:00      NaN   43.286      NaN                23.0
# 2019-05-07 03:00:00     50.5   35.758     25.0                19.0
# 2019-05-07 04:00:00     45.0   35.758     27.7                19.0
# 2019-05-07 05:00:00      NaN   30.112     50.4                16.0
# 2019-05-07 06:00:00      NaN      NaN     61.9                 NaN
#
#                      london_mg_per_cubic
# datetime
# 2019-05-07 02:00:00               43.286
# 2019-05-07 03:00:00               35.758
# 2019-05-07 04:00:00               35.758
# 2019-05-07 05:00:00               30.112
# 2019-05-07 06:00:00                  NaN

# %%
air_quality_renamed = air_quality_renamed.assign(ratio=lambda x: (x["betr801"] / x["fr04014"]))

air_quality_renamed.head()
# Out:
#                      betr801  new_col  fr04014  london westminster  \
# datetime
# 2019-05-07 02:00:00      NaN   43.286      NaN                23.0
# 2019-05-07 03:00:00     50.5   35.758     25.0                19.0
# 2019-05-07 04:00:00     45.0   35.758     27.7                19.0
# 2019-05-07 05:00:00      NaN   30.112     50.4                16.0
# 2019-05-07 06:00:00      NaN      NaN     61.9                 NaN
#
#                      london_mg_per_cubic     ratio
# datetime
# 2019-05-07 02:00:00               43.286       NaN
# 2019-05-07 03:00:00               35.758  2.020000
# 2019-05-07 04:00:00               35.758  1.624549
# 2019-05-07 05:00:00               30.112       NaN
# 2019-05-07 06:00:00                  NaN       NaN

# %%
air_quality.agg({
    'station_antwerp': ['min', 'max', 'median', 'skew'],
    'station_paris': ['min', 'max', 'mean', 'skew'],
    'station_london': ['min', 'max', 'median', 'mean']
})
# Out:
#         station_antwerp  station_paris  station_london
# max            74.50000      97.000000        97.00000
# mean                NaN      27.740538        24.77709
# median         23.00000            NaN        25.00000
# min             7.50000       0.000000         0.00000
# skew            1.08226       1.161128             NaN

# %%
air_quality.sum()
# Out:
# station_antwerp         2449.000000
# station_paris          27851.500000
# station_london         24009.000000
# london_mg_per_cubic    45184.938000
# ratio_paris_antwerp      123.884818
# dtype: float64

# %%
((air_quality - air_quality.mean()) / air_quality.std())
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN       -0.158465
# 2019-05-07 03:00:00         1.949300      -0.179287       -0.515150
# 2019-05-07 04:00:00         1.515615      -0.002652       -0.515150
# 2019-05-07 05:00:00              NaN       1.482392       -0.782664
# 2019-05-07 06:00:00              NaN       2.234726             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN      -0.414801             NaN
# 2019-06-20 23:00:00              NaN      -0.185829             NaN
# 2019-06-21 00:00:00              NaN      -0.081157             NaN
# 2019-06-21 01:00:00              NaN      -0.388633             NaN
# 2019-06-21 02:00:00              NaN      -0.506389             NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00            -0.158465                  NaN
# ...

# %%
air_quality.cumsum()
# Out:
#                      station_antwerp  station_paris  station_london  \
# datetime
# 2019-05-07 02:00:00              NaN            NaN            23.0
# 2019-05-07 03:00:00             50.5           25.0            42.0
# 2019-05-07 04:00:00             95.5           52.7            61.0
# 2019-05-07 05:00:00              NaN          103.1            77.0
# 2019-05-07 06:00:00              NaN          165.0             NaN
# ...                              ...            ...             ...
# 2019-06-20 22:00:00              NaN        27758.3             NaN
# 2019-06-20 23:00:00              NaN        27783.2             NaN
# 2019-06-21 00:00:00              NaN        27809.7             NaN
# 2019-06-21 01:00:00              NaN        27831.5             NaN
# 2019-06-21 02:00:00              NaN        27851.5             NaN
#
#                      london_mg_per_cubic  ratio_paris_antwerp
# datetime
# 2019-05-07 02:00:00               43.286                  NaN
# ...

# %%
url = "https://raw.githubusercontent.com/pandas-dev/pandas/master/doc/data/titanic.csv"

titanic = pd.read_csv(url, index_col=0)

titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic[["Age", "Fare"]].describe()
# Out:
#               Age        Fare
# count  714.000000  891.000000
# mean    29.699118   32.204208
# std     14.526497   49.693429
# min      0.420000    0.000000
# 25%     20.125000    7.910400
# 50%     28.000000   14.454200
# 75%     38.000000   31.000000
# max     80.000000  512.329200

# %%
print(titanic[["Sex", "Age"]].groupby("Sex").mean())
print(titanic[["Sex", "Age"]].groupby("Sex").sum())
print(titanic.groupby("Sex").agg({'Age': 'mean', 'Fare': 'sum'}).rename({'Age': 'age_avg', 'Fare': 'total_fare'}))
print(titanic.groupby("Sex")["Age"].mean())
# Out:
#               Age
# Sex
# female  27.915709
# male    30.726645
#              Age
# Sex
# female   7286.00
# male    13919.17
#               Age        Fare
# Sex
# female  27.915709  13966.6628
# male    30.726645  14727.2865
# Sex
# female    27.915709
# male      30.726645
# Name: Age, dtype: float64

# %%
titanic["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
titanic.sort_values(by="Age", ascending= False).head()
# Out:
#              Survived  Pclass                                  Name   Sex  \
# PassengerId
# 631                 1       1  Barkworth, Mr. Algernon Henry Wilson  male
# 852                 0       3                   Svensson, Mr. Johan  male
# 494                 0       1               Artagaveytia, Mr. Ramon  male
# 97                  0       1             Goldschmidt, Mr. George B  male
# 117                 0       3                  Connors, Mr. Patrick  male
#
#               Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 631          80.0      0      0     27042  30.0000   A23        S
# 852          74.0      0      0    347060   7.7750   NaN        S
# 494          71.0      0      0  PC 17609  49.5042   NaN        C
# 97           71.0      0      0  PC 17754  34.6542    A5        C
# 117          70.5      0      0    370369   7.7500   NaN        Q

# %%
titanic.sort_values(by=['Pclass', 'Age'], ascending=False).head()
# Out:
#              Survived  Pclass                       Name     Sex   Age  SibSp  \
# PassengerId
# 852                 0       3        Svensson, Mr. Johan    male  74.0      0
# 117                 0       3       Connors, Mr. Patrick    male  70.5      0
# 281                 0       3           Duane, Mr. Frank    male  65.0      0
# 484                 1       3     Turkula, Mrs. (Hedwig)  female  63.0      0
# 327                 0       3  Nysveen, Mr. Johan Hansen    male  61.0      0
#
#              Parch  Ticket    Fare Cabin Embarked
# PassengerId
# 852              0  347060  7.7750   NaN        S
# 117              0  370369  7.7500   NaN        Q
# 281              0  336439  7.7500   NaN        Q
# 484              0    4134  9.5875   NaN        S
# 327              0  345364  6.2375   NaN        S

# %%
titanic.groupby(["Pclass"]).head(2) # use 2 measurements (head) for each Pclass (groupby)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 10                  1       2
# 16                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female  55.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# ...

# %%
titanic.pivot(columns='Pclass', values='Fare').head()
# Out:
# Pclass             1   2      3
# PassengerId
# 1                NaN NaN  7.250
# 2            71.2833 NaN    NaN
# 3                NaN NaN  7.925
# 4            53.1000 NaN    NaN
# 5                NaN NaN  8.050

# %% [markdown]
# In the case of pivot(), the data is only rearranged. When multiple values need to be aggregated (in this specific case, the values on different time steps) pivot_table() can be used, providing an aggregation function (e.g. mean) on how to combine these values.
#
# Pivot table is a well known concept in spreadsheet

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
pokemon.pivot_table(values='HP', columns='Legendary', index = 'Type 1', aggfunc='max')
# Out:
# Legendary  False  True
# Type 1
# Bug         86.0    NaN
# Dark       110.0  126.0
# Dragon     108.0  125.0
# Electric    90.0   90.0
# Fairy      101.0  126.0
# Fighting   144.0    NaN
# Fire       110.0  115.0
# Flying      85.0   79.0
# Ghost      150.0  150.0
# Grass      123.0  100.0
# Ground     115.0  100.0
# Ice        110.0   90.0
# Normal     255.0  120.0
# Poison     105.0    NaN
# Psychic    190.0  106.0
# Rock       123.0   91.0
# Steel       80.0  100.0
# Water      170.0  100.0

# %%
a = air_quality.reset_index().melt(id_vars='datetime', value_vars=["station_antwerp", "station_paris"], value_name="NO_2",var_name="id_location")

print(a.shape)
a.head()
# Out:
# (2070, 3)
#              datetime      id_location  NO_2
# 0 2019-05-07 02:00:00  station_antwerp   NaN
# 1 2019-05-07 03:00:00  station_antwerp  50.5
# 2 2019-05-07 04:00:00  station_antwerp  45.0
# 3 2019-05-07 05:00:00  station_antwerp   NaN
# 4 2019-05-07 06:00:00  station_antwerp   NaN

# %%
b = air_quality.reset_index().melt(id_vars='datetime', value_vars="station_london", value_name="NO_2",var_name="id_location")

print(b.shape)
b.head()
# Out:
# (1035, 3)
#              datetime     id_location  NO_2
# 0 2019-05-07 02:00:00  station_london  23.0
# 1 2019-05-07 03:00:00  station_london  19.0
# 2 2019-05-07 04:00:00  station_london  19.0
# 3 2019-05-07 05:00:00  station_london  16.0
# 4 2019-05-07 06:00:00  station_london   NaN

# %%
c = pd.concat([a, b], axis=0)

print(c.shape)
c.head()
# Out:
# (3105, 3)
#              datetime      id_location  NO_2
# 0 2019-05-07 02:00:00  station_antwerp   NaN
# 1 2019-05-07 03:00:00  station_antwerp  50.5
# 2 2019-05-07 04:00:00  station_antwerp  45.0
# 3 2019-05-07 05:00:00  station_antwerp   NaN
# 4 2019-05-07 06:00:00  station_antwerp   NaN

# %%
d = pd.merge(a, b, how= 'left', on='datetime')

print(d.shape)
d.head()
# Out:
# (2070, 5)
#              datetime    id_location_x  NO_2_x   id_location_y  NO_2_y
# 0 2019-05-07 02:00:00  station_antwerp     NaN  station_london    23.0
# 1 2019-05-07 03:00:00  station_antwerp    50.5  station_london    19.0
# 2 2019-05-07 04:00:00  station_antwerp    45.0  station_london    19.0
# 3 2019-05-07 05:00:00  station_antwerp     NaN  station_london    16.0
# 4 2019-05-07 06:00:00  station_antwerp     NaN  station_london     NaN

# %%
b = b.rename(
        columns={
            "datetime": "date"})

b.head()
# Out:
#                  date     id_location  NO_2
# 0 2019-05-07 02:00:00  station_london  23.0
# 1 2019-05-07 03:00:00  station_london  19.0
# 2 2019-05-07 04:00:00  station_london  19.0
# 3 2019-05-07 05:00:00  station_london  16.0
# 4 2019-05-07 06:00:00  station_london   NaN

# %%
e = pd.merge(a, b, how= 'left', left_on='datetime',  right_on='date')

print(e.shape)
e.head()
# Out:
# (2070, 6)
#              datetime    id_location_x  NO_2_x                date  \
# 0 2019-05-07 02:00:00  station_antwerp     NaN 2019-05-07 02:00:00
# 1 2019-05-07 03:00:00  station_antwerp    50.5 2019-05-07 03:00:00
# 2 2019-05-07 04:00:00  station_antwerp    45.0 2019-05-07 04:00:00
# 3 2019-05-07 05:00:00  station_antwerp     NaN 2019-05-07 05:00:00
# 4 2019-05-07 06:00:00  station_antwerp     NaN 2019-05-07 06:00:00
#
#     id_location_y  NO_2_y
# 0  station_london    23.0
# 1  station_london    19.0
# 2  station_london    19.0
# 3  station_london    16.0
# 4  station_london     NaN

# %%
weather = pd.read_csv('weather.csv')

weather.head()
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
weather['EST'] = pd.to_datetime(weather['EST'])

weather.head()
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0 2016-01-01           38        23        52                 30.03
# 1 2016-01-02           36        18        46                 30.02
# 2 2016-01-03           40        21        47                 29.86
# 3 2016-01-04           25         9        44                 30.05
# 4 2016-01-05           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
weather["EST"].min(), weather["EST"].max()
# Out:
# (Timestamp('2016-01-01 00:00:00'), Timestamp('2016-01-31 00:00:00'))

# %%
weather["EST"].max() - weather["EST"].min()
# Out:
# Timedelta('30 days 00:00:00')

# %%
weather['date'] = weather.EST.dt.day

weather.head()
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0 2016-01-01           38        23        52                 30.03
# 1 2016-01-02           36        18        46                 30.02
# 2 2016-01-03           40        21        47                 29.86
# 3 2016-01-04           25         9        44                 30.05
# 4 2016-01-05           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees  date
# 0             281     1
# 1             275     2
# 2             277     3
# 3             345     4
# ...

# %%
weather.groupby(weather.EST.dt.dayofweek)['Temperature'].mean()
# Out:
# EST
# 0    29.25
# 1    30.00
# 2    33.00
# 3    34.25
# 4    36.40
# 5    37.40
# 6    40.00
# Name: Temperature, dtype: float64

# %%
fig, axs = plt.subplots(figsize = (10, 5))

weather.groupby(weather.EST.dt.dayofweek)['Temperature'].mean().plot.bar(ax = axs)

axs.set_ylabel('Temperature')
axs.set_xlabel('day of the week')
# Out:
# Text(0.5, 0, 'day of the week')

# %%
weather['Temperature'].plot.line()

# %%
weather.set_index('EST', inplace=True)

weather.head()
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# EST
# 2016-01-01           38        23        52                 30.03
# 2016-01-02           36        18        46                 30.02
# 2016-01-03           40        21        47                 29.86
# 2016-01-04           25         9        44                 30.05
# 2016-01-05           20        -3        41                 30.57
#
#             VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# EST
# 2016-01-01               10           8.0               0           5    NaN
# 2016-01-02               10           7.0               0           3    NaN
# 2016-01-03               10           8.0               0           1    NaN
# 2016-01-04               10           9.0               0           3    NaN
# 2016-01-05               10           5.0               0           0    NaN
#
#             WindDirDegrees  date
# EST
# 2016-01-01             281     1
# ...

# %%
weather.resample('D').max()['Temperature'].plot(style = "-o", figsize = (10,5))

#weather.index.freq

# %%
titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# ...

# %%
titanic['Name'].str.lower()
# Out:
# PassengerId
# 1                                braund, mr. owen harris
# 2      cumings, mrs. john bradley (florence briggs th...
# 3                                 heikkinen, miss. laina
# 4           futrelle, mrs. jacques heath (lily may peel)
# 5                               allen, mr. william henry
#                              ...
# 887                                montvila, rev. juozas
# 888                         graham, miss. margaret edith
# 889             johnston, miss. catherine helen "carrie"
# 890                                behr, mr. karl howell
# 891                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
titanic['Name'].str.split(',')
# Out:
# PassengerId
# 1                             [Braund,  Mr. Owen Harris]
# 2      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 3                              [Heikkinen,  Miss. Laina]
# 4        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 5                            [Allen,  Mr. William Henry]
#                              ...
# 887                             [Montvila,  Rev. Juozas]
# 888                      [Graham,  Miss. Margaret Edith]
# 889          [Johnston,  Miss. Catherine Helen "Carrie"]
# 890                             [Behr,  Mr. Karl Howell]
# 891                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
titanic['surname'] = titanic['Name'].str.split(',').str.get(0)

titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked    surname
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S     Braund
# 2                1      0          PC 17599  71.2833   C85        C    Cumings
# ...

# %%
titanic[titanic["Name"].str.contains("Countess")]
# Out:
#              Survived  Pclass  \
# PassengerId
# 760                 1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 760          Rothes, the Countess. of (Lucy Noel Martha Dye...  female  33.0
#
#              SibSp  Parch  Ticket  Fare Cabin Embarked surname
# PassengerId
# 760              0      0  110152  86.5   B77        S  Rothes

# %%
titanic["Name"].str.len()
# Out:
# PassengerId
# 1      23
# 2      51
# 3      22
# 4      44
# 5      24
#        ..
# 887    21
# 888    28
# 889    40
# 890    21
# 891    19
# Name: Name, Length: 891, dtype: int64

# %% [markdown]
# Need to get the corresponding location, preferably the index label, in the table for which the name length is the largest. The idxmax() method does exactly that.

# %%
titanic["Name"].str.len().idxmax()
# Out:
# 308

# %%
titanic.loc[titanic["Name"].str.len().idxmax(), "Name"]
# Out:
# 'Penasco y Castellana, Mrs. Victor de Satode (Maria Josefa Perez de Soto y Vallejo)'

# %%
titanic["Sex_short"] = titanic["Sex"].replace({"male": "M", "female": "F"})

titanic.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# ...
